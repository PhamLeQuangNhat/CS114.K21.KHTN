# %%
# %cd '/content/drive/My Drive/ML/Final'
# Out:
# /content/drive/My Drive/ML/Final

# %%
ls
# Out:
# Data/                       H5PY/                   Save_features.ipynb
# dataloader/                 image/                  Save_model.ipynb
# Description.ipynb           lenet_train.py          shallownet_train.py
# env.txt                     minivggnet_train.py     Train_model_raw_data/
# Evaluation.ipynb            Model_raw_data.ipynb    Tuning_hyperparameter.ipynb
# Evaluation_model_raw.ipynb  nn/                     Web.ipynb
# Evaluation_predict.ipynb    preprocessing/
# Feature_Extraction/         Save_feature_raw_data/

# %% [markdown]
# # **4. Save features**

# %% [markdown]
# ## **4.1 Import các thư viện cần thiết**

# %%
from dataloader.simpledatasetloader import SimpleDatasetLoader
from preprocessing.simplepreprocessor import SimplePreprocessor
from Feature_Extraction.hog import HOG
from Feature_Extraction.localbinarypatterns import LocalBinaryPatterns

import numpy as np 
import h5py
import os
from imutils import paths
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## **4.2 Save features train**

# %%
imagePaths = 'Data/Raw_train_data'

# %%
# grab the list of images 
print("[INFO] loading images...")
imagePaths_train = list(paths.list_images(imagePaths))
# Out:
# [INFO] loading images...

# %%
print(len(imagePaths_train))
# Out:
# 12362

# %% [markdown]
# ### **4.2.1 Normal vector**

# %%
data_raw_normal = 'H5PY/raw_train/train_normal.h5'
labels_raw_h5    = 'H5PY/raw_train/labels_train.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)
sdl = SimpleDatasetLoader(preprocessors=[sp])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_train,verbose=100)
# Out:
# [INFO] processed 100/12362
# [INFO] processed 200/12362
# [INFO] processed 300/12362
# [INFO] processed 400/12362
# [INFO] processed 500/12362
# [INFO] processed 600/12362
# [INFO] processed 700/12362
# [INFO] processed 800/12362
# [INFO] processed 900/12362
# [INFO] processed 1000/12362
# [INFO] processed 1100/12362
# [INFO] processed 1200/12362
# [INFO] processed 1300/12362
# [INFO] processed 1400/12362
# [INFO] processed 1500/12362
# [INFO] processed 1600/12362
# [INFO] processed 1700/12362
# [INFO] processed 1800/12362
# [INFO] processed 1900/12362
# [INFO] processed 2000/12362
# [INFO] processed 2100/12362
# [INFO] processed 2200/12362
# [INFO] processed 2300/12362
# [INFO] processed 2400/12362
# [INFO] processed 2500/12362
# [INFO] processed 2600/12362
# [INFO] processed 2700/12362
# [INFO] processed 2800/12362
# [INFO] processed 2900/12362
# [INFO] processed 3000/12362
# [INFO] processed 3100/12362
# [INFO] processed 3200/12362
# [INFO] processed 3300/12362
# [INFO] processed 3400/12362
# [INFO] processed 3500/12362

# %%
# scale the raw pixel intensities to the range [0, 1]
data = data.astype("float") / 255.0

# %%
# reshape the data matrix
data = data.reshape((data.shape[0],3072))

# %%
# encode the labels as integers
le = LabelEncoder()
labels = le.fit_transform(labels)

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_raw_normal, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))
# Out:
# <HDF5 dataset "dataset": shape (10876, 3072), type "<f8">

# %%
h5f_label = h5py.File(labels_raw_h5, 'w')
h5f_label.create_dataset('dataset', data=np.array(labels))
# Out:
# <HDF5 dataset "dataset": shape (10876,), type "<i8">

# %%
data.shape
# Out:
# (10876, 3072)

# %%
labels.shape
# Out:
# (10876,)

# %%
h5f_data.close()
h5f_label.close()

# %% [markdown]
# ###**4.2.2 Local Binary Patterns**

# %%
data_raw_lbps = 'H5PY/raw_train/train_lbps.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)

# initialize local binary patterns
lbps = LocalBinaryPatterns(24,8)

sdl = SimpleDatasetLoader(preprocessors=[sp,lbps])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_train,verbose=100)

# %%
data = data.astype("float")

# %%
data.shape
# Out:
# (10876, 26)

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_raw_lbps, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))
# Out:
# <HDF5 dataset "dataset": shape (10876, 26), type "<f8">

# %%
h5f_data.close()

# %% [markdown]
# ###**4.2.3 Histogram**

# %%
data_raw_hog = 'H5PY/raw_train/train_hog.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)

# initialize histograms
hg = HOG(9)

sdl = SimpleDatasetLoader(preprocessors=[sp,hg])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_train,verbose=100)
# Out:
# [INFO] processed 100/12362
# [INFO] processed 200/12362
# [INFO] processed 300/12362
# [INFO] processed 400/12362
# [INFO] processed 500/12362
# [INFO] processed 600/12362
# [INFO] processed 700/12362
# [INFO] processed 800/12362
# [INFO] processed 900/12362
# [INFO] processed 1000/12362
# [INFO] processed 1100/12362
# [INFO] processed 1200/12362
# [INFO] processed 1300/12362
# [INFO] processed 1400/12362
# [INFO] processed 1500/12362
# [INFO] processed 1600/12362
# [INFO] processed 1700/12362
# [INFO] processed 1800/12362
# [INFO] processed 1900/12362
# [INFO] processed 2000/12362
# [INFO] processed 2100/12362
# [INFO] processed 2200/12362
# [INFO] processed 2300/12362
# [INFO] processed 2400/12362
# [INFO] processed 2500/12362
# [INFO] processed 2600/12362
# [INFO] processed 2700/12362
# [INFO] processed 2800/12362
# [INFO] processed 2900/12362
# [INFO] processed 3000/12362
# [INFO] processed 3100/12362
# [INFO] processed 3200/12362
# [INFO] processed 3300/12362
# [INFO] processed 3400/12362
# [INFO] processed 3500/12362
# [INFO] processed 3600/12362
# [INFO] processed 3700/12362
# [INFO] processed 3800/12362
# [INFO] processed 3900/12362
# [INFO] processed 4000/12362
# [INFO] processed 4100/12362
# [INFO] processed 4200/12362
# [INFO] processed 4300/12362
# [INFO] processed 4400/12362
# [INFO] processed 4500/12362
# [INFO] processed 4600/12362
# [INFO] processed 4700/12362
# [INFO] processed 4800/12362
# [INFO] processed 4900/12362
# [INFO] processed 5000/12362
# [INFO] processed 5100/12362
# [INFO] processed 5200/12362
# [INFO] processed 5300/12362
# [INFO] processed 5400/12362
# [INFO] processed 5500/12362
# [INFO] processed 5600/12362
# [INFO] processed 5700/12362
# [INFO] processed 5800/12362
# [INFO] processed 5900/12362
# [INFO] processed 6000/12362
# [INFO] processed 6100/12362
# [INFO] processed 6200/12362
# [INFO] processed 6300/12362
# [INFO] processed 6400/12362
# [INFO] processed 6500/12362
# [INFO] processed 6600/12362
# [INFO] processed 6700/12362
# [INFO] processed 6800/12362
# [INFO] processed 6900/12362
# [INFO] processed 7000/12362
# [INFO] processed 7100/12362
# [INFO] processed 7200/12362
# [INFO] processed 7300/12362
# [INFO] processed 7400/12362
# [INFO] processed 7500/12362
# [INFO] processed 7600/12362
# [INFO] processed 7700/12362
# [INFO] processed 7800/12362
# [INFO] processed 7900/12362
# [INFO] processed 8000/12362
# [INFO] processed 8100/12362
# [INFO] processed 8200/12362
# [INFO] processed 8300/12362
# [INFO] processed 8400/12362
# [INFO] processed 8500/12362
# [INFO] processed 8600/12362
# [INFO] processed 8700/12362
# [INFO] processed 8800/12362
# [INFO] processed 8900/12362
# [INFO] processed 9000/12362
# [INFO] processed 9100/12362
# [INFO] processed 9200/12362
# [INFO] processed 9300/12362
# [INFO] processed 9400/12362
# [INFO] processed 9500/12362
# [INFO] processed 9600/12362
# [INFO] processed 9700/12362
# [INFO] processed 9800/12362
# [INFO] processed 9900/12362
# [INFO] processed 10000/12362
# [INFO] processed 10100/12362
# [INFO] processed 10200/12362
# [INFO] processed 10300/12362
# [INFO] processed 10400/12362
# [INFO] processed 10500/12362
# [INFO] processed 10600/12362
# [INFO] processed 10700/12362
# [INFO] processed 10800/12362
# [INFO] processed 10900/12362
# [INFO] processed 11000/12362
# [INFO] processed 11100/12362
# [INFO] processed 11200/12362
# [INFO] processed 11300/12362
# [INFO] processed 11400/12362
# [INFO] processed 11500/12362
# [INFO] processed 11600/12362
# [INFO] processed 11700/12362
# [INFO] processed 11800/12362
# [INFO] processed 11900/12362
# [INFO] processed 12000/12362
# [INFO] processed 12100/12362
# [INFO] processed 12200/12362
# [INFO] processed 12300/12362

# %%
data = data.astype("float")

# %%
data.shape
# Out:
# (12362, 144)

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_raw_hog, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))
# Out:
# <HDF5 dataset "dataset": shape (12362, 144), type "<f8">

# %%
h5f_data.close()

# %% [markdown]
# ## **4.3 Save features predict**

# %%
imagePaths = 'Data/Predict'

# %%
data_predict_normal = 'H5PY/predict/data.h5'
labels_predict_h5    = 'H5PY/predict/labels.h5'

# %%
# grab the list of images 
print("[INFO] loading images...")
imagePaths_predict = list(paths.list_images(imagePaths))
# Out:
# [INFO] loading images...

# %%
print(len(imagePaths_predict))
# Out:
# 120

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)
sdl = SimpleDatasetLoader(preprocessors=[sp])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_predict,verbose=100)
# Out:
# [INFO] processed 100/120

# %%
# scale the raw pixel intensities to the range [0, 1]
data = data.astype("float") / 255.0

# %%
# reshape the data matrix
data = data.reshape((data.shape[0],3072))

# %%
labels[100]
# Out:
# 'Mango'

# %%
# encode the labels as integers
le = LabelEncoder()
labels = le.fit_transform(labels)

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_predict_normal, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))
# Out:
# <HDF5 dataset "dataset": shape (120, 3072), type "<f8">

# %%
h5f_label = h5py.File(labels_predict_h5, 'w')
h5f_label.create_dataset('dataset', data=np.array(labels))
# Out:
# <HDF5 dataset "dataset": shape (120,), type "<i8">

# %%
h5f_data.close()
h5f_label.close()
