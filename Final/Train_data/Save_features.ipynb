# %%
# %cd '/content/drive/My Drive/ML/CS114.K21.KHTN/Final/'
# Out:
# /content/drive/My Drive/ML/CS114.K21.KHTN/Final

# %% [markdown]
# # **4. Save features**

# %% [markdown]
# ## **4.1 Import các thư viện cần thiết**

# %%
from dataloader.simpledatasetloader import SimpleDatasetLoader
from preprocessing.simplepreprocessor import SimplePreprocessor
from Feature_Extraction.hog import HOG
from Feature_Extraction.localbinarypatterns import LocalBinaryPatterns
from Feature_Extraction.Hu_moments import Hu_moments
import numpy as np 
import h5py
import os
from imutils import paths
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## **4.2 Save features train**

# %%
in_data_train = 'Data/Train_data'

# %%
# grab the list of images 
print("[INFO] loading images...")
imagePaths_train = list(paths.list_images(in_data_train))

# %% [markdown]
# ### **4.2.1 Normal vector**

# %%
data_normal = 'H5PY/train/train_normal.h5'
labels_h5    = 'H5PY/train/labels_train.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)
sdl = SimpleDatasetLoader(preprocessors=[sp])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_train,verbose=100)

# %%
# scale the raw pixel intensities to the range [0, 1]
data = data.astype("float") / 255.0

# %%
# reshape the data matrix
data = data.reshape((data.shape[0],3072))

# %%
# encode the labels as integers
le = LabelEncoder()
labels = le.fit_transform(labels)

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_normal, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))

# %%
h5f_label = h5py.File(labels_h5, 'w')
h5f_label.create_dataset('dataset', data=np.array(labels))

# %%
h5f_data.close()
h5f_label.close()

# %% [markdown]
# ###**4.2.2 Local Binary Patterns**

# %%
data_lbps = 'H5PY/train/train_lbps.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)

# initialize local binary patterns
lbps = LocalBinaryPatterns(24,8)

sdl = SimpleDatasetLoader(preprocessors=[sp,lbps])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_train,verbose=100)

# %%
data = data.astype("float")

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_lbps, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))

# %%
h5f_data.close()

# %% [markdown]
# ###**4.2.3 Histogram**

# %%
data_hog = 'H5PY/train/train_hog.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)

# initialize histograms
hg = HOG(9)

sdl = SimpleDatasetLoader(preprocessors=[sp,hg])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_train,verbose=100)

# %%
data = data.astype("float")

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_hog, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))

# %%
h5f_data.close()

# %% [markdown]
# ###**4.2.4 Hu moments**

# %%
data_hu = 'H5PY/train/train_hu.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)
hum = Hu_moments(9)
sdl = SimpleDatasetLoader(preprocessors=[sp,hum])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_train,verbose=100)

# %%
data = data.astype("float")

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_hu, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))

# %%
h5f_data.close()

# %% [markdown]
# ## **4.3 Save features test**

# %%
in_data_test = 'Data/Test_data'

# %%
# grab the list of images 
print("[INFO] loading images...")
imagePaths_test = list(paths.list_images(in_data_test))

# %% [markdown]
# ### **4.3.1 Normal vector**

# %%
data_normal = 'H5PY/test/test_normal.h5'
label_h5    = 'H5PY/test/labels_test.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)
sdl = SimpleDatasetLoader(preprocessors=[sp])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_test,verbose=100)

# %%
# scale the raw pixel intensities to the range [0, 1]
data = data.astype("float") / 255.0

# %%
# reshape the data matrix
data = data.reshape((data.shape[0],3072))

# %%
# encode the labels as integers
le = LabelEncoder()
labels = le.fit_transform(labels)

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_normal, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))

# %%
h5f_label = h5py.File(labels_h5, 'w')
h5f_label.create_dataset('dataset', data=np.array(labels))

# %%
h5f_data.close()
h5f_label.close()

# %% [markdown]
# ###**4.3.2 Local Binary Patterns**

# %%
data_lbps = 'H5PY/test/test_lbps.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)

# initialize local binary patterns
lbps = LocalBinaryPatterns(24,8)

sdl = SimpleDatasetLoader(preprocessors=[sp,lbps])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_test,verbose=100)

# %%
data = data.astype("float")

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_lbps, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))

# %%
h5f_data.close()

# %% [markdown]
# ###**4.3.3 Histogram**

# %%
data_hog = 'H5PY/test/test_hog.h5'

# %%
# initialize image preprocessor
sp = SimplePreprocessor(32,32)

# initialize histograms
hg = HOG(9)

sdl = SimpleDatasetLoader(preprocessors=[sp,hg])

# load dataset from memory
(data, labels) = sdl.load(imagePaths_test,verbose=100)

# %%
data = data.astype("float")

# %%
# save the feature vector using HDF5
h5f_data = h5py.File(data_hog, 'w')
h5f_data.create_dataset('dataset', data=np.array(data))

# %%
h5f_data.close()

# %% [markdown]
# ###**4.3.4 Hu moment**
